# %%
import pandas as pd

# %%
customers = pd.read_csv('./DatosPrueba/caracteristicas_clientes.csv')
products = pd.read_csv('./DatosPrueba/caracteristicas_productos.csv')
pos = pd.read_csv('./DatosPrueba/caracteristicas_puntos_de_venta.csv')
history = pd.read_csv('./DatosPrueba/historico_ventas.csv')
test_set = pd.read_csv('./DatosPrueba/set_testeo.csv')

# %%
test_set
# Out:
#      Id_Producto Cliente  Punto_de_Venta     Familia    Subfamilia  Formato  \
# 0            P51      C0              11  Familia_22  Subfamilia_0   Grande
# 1            P69      C1              12  Familia_10  Subfamilia_4  Pequeño
# 2            P17      C2              12  Familia_17  Subfamilia_4  Mediano
# 3             P4      C3              12   Familia_5  Subfamilia_6  Mediano
# 4            P51      C4              10  Familia_22  Subfamilia_0   Grande
# ...          ...     ...             ...         ...           ...      ...
# 2635         P65      C7               1  Familia_12  Subfamilia_1  Mediano
# 2636         P66     C15               5  Familia_10  Subfamilia_0  Mediano
# 2637         P67     C13               1  Familia_21  Subfamilia_5   Grande
# 2638         P68     C21               4  Familia_20  Subfamilia_7  Mediano
# 2639         P69     C17              13  Familia_10  Subfamilia_4  Pequeño
#
# ...
